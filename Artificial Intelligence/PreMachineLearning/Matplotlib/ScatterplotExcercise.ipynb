# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import requests

# %%
x = np.random.random(1000)
y = np.random.random(1000)
# coords = dict(zip(x, y))
# colors = np.array(list(map()))
colors = np.array(list(map(lambda x, y: 'red' if (x > 0.5 and y > 0.5) or (x < 0.5 and y < 0.5) else 'blue', x, y)))
plt.scatter(x, y,  c=colors, marker='o', alpha=0.3)
plt.show()
